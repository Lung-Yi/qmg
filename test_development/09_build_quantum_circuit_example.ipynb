# %%
import sys
sys.path.append("../")
from qmg.generator import MoleculeGenerator
from qmg.utils import MoleculeQuantumStateGenerator
from rdkit import RDLogger
import pickle
RDLogger.DisableLog('rdApp.*')

num_heavy_atom = 5 # Change the number of heavy atoms here
temperature = 0.2 # recommended hyperparameter
random_seed = 0 # random seed for generating the weight vector (thetas)

# %%
mg = MoleculeGenerator(num_heavy_atom, temperature=temperature, 
                           remove_bond_disconnection=True, chemistry_constraint=True)
mg.generate_quantum_circuit(random_seed)
mg.qc.draw()

# mg.qc stands for the qiskit quantum circuit
# Out:
#       ┌────────────┐                                       ┌─┐                 »
#  q_0: ┤ Ry(2.6528) ├──■───────────────────────■────────────┤M├─────────────────»
#       └───┬───┬────┘┌─┴─┐               ┌─────┴──────┐     └╥┘              ┌─┐»
#  q_1: ────┤ X ├─────┤ X ├───────■───────┤ Ry(2.3812) ├──■───╫───────────────┤M├»
#       ┌───┴───┴────┐└───┘┌──────┴──────┐└────────────┘┌─┴─┐ ║               └╥┘»
#  q_2: ┤ Ry(1.3213) ├─────┤ Ry(0.81341) ├──────■───────┤ X ├─╫───────■────────╫─»
#       ├────────────┤     └─────────────┘    ┌─┴─┐     └───┘ ║ ┌─────┴──────┐ ║ »
#  q_3: ┤ Ry(1.6062) ├────────────────────────┤ X ├───────────╫─┤ Ry(1.2721) ├─╫─»
#       └───┬───┬────┘                        └───┘           ║ └────────────┘ ║ »
#  q_4: ────┤ X ├─────────────────────────────────────────────╫────────────────╫─»
#           └───┘                                             ║                ║ »
#  q_5: ──────────────────────────────────────────────────────╫────────────────╫─»
# ...
